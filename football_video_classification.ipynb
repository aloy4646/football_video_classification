# %% [markdown]
# <a href="https://colab.research.google.com/github/aloy4646/football_video_classification/blob/main/football_video_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import pathlib

import cv2
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, Sequential

from tensorflow.keras.layers import TimeDistributed, Conv2D, Dense, MaxPool2D, Flatten, LSTM

# %%
HEIGHT = 224
WIDTH = 224

# %%
class FrameGeneration:
  def __init__(self, path, n_frames, training = False):
    """ Mengembalikan set frames beserta label terkait.

      Args:
        path: Path file video.
        n_frames: Jumlah frames.
        training: Boolean untuk menentukan apakah dataset training sedang dibuat.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
          # self.path.iterdir() --> (dataset_final/train/card), (dataset_final/train/celebration), (dataset_final/train/corner)

    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    # video_paths = list(self.path.glob('*/*.avi'))
    video_paths = list(self.path.glob('*/*.mp4'))
          # video_paths --> '/dataset_final/train/substitution/*.mp4'

    classes = [p.parent.name for p in video_paths]
    return video_paths, classes

  def frames_from_video_file(self, video_path, n_frames, output_size = (HEIGHT,WIDTH)):
    """
      Membuat frames dari setiap file video yang ada untuk setiap kategori.

      Args:
        video_path: Path file video.
        n_frames: Jumlah frames yang akan dibuat per file video.
        output_size: Ukuran piksel dari frame keluaran.

      Return:
        Array NumPy dari frames dengan bentuk (n_frames, HEIGHT, WIDTH, saluran).
    """
    # Baca setiap frame video
    result = []
    src = cv2.VideoCapture(str(video_path))

    video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

    # Frame step fleksibel mengikuti panjang dari sumber video
    frame_step = max(int(video_length / (n_frames-1)), 1)

    need_length = 1 + (n_frames-1) * frame_step

    if need_length > video_length:
      start = 0
    else:
      max_start = video_length - need_length
      start = random.randint(0, max_start + 1)

    src.set(cv2.CAP_PROP_POS_FRAMES, start)

    # ret adalah boolean yang menunjukkan apakah pembacaan berhasil, frame adalah gambar itu sendiri
    ret, frame = src.read()
    result.append(self.format_frames(frame, output_size))

    for _ in range(n_frames - 1):
      for _ in range(frame_step):
        ret, frame = src.read()
      if ret and frame is not None:
        frame = self.format_frames(frame, output_size)
        result.append(frame)
      else:
        result.append(np.zeros_like(result[0]))

    src.release()
    result = np.array(result)[..., [2, 1, 0]]
          # BGR --> RGB
    return result


  def format_frames(self, frame, output_size):
      """
      Menambahkan padding dan meresize frame dari video.

      Args:
          frame: frame yang perlu diresize dan dipad.
          output_size: Ukuran piksel dari frame keluaran.

          Return:
            Frame yang diformat dengan padding sesuai ukuran keluaran.
      """
      # return resized_frame
      frame = tf.image.convert_image_dtype(frame, tf.float32)
      frame = tf.image.resize_with_pad(frame, *output_size)
      return frame

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))
                  # video_paths = ['/path/to/video1.mp4', '/path/to/video2.mp4', '/path/to/video3.mp4']
                  # classes = ['class1', 'class2', 'class3']
                  # zip --> ('/path/to/video1.mp4', 'class1'), ('/path/to/video2.mp4', 'class2'), ('/path/to/video3.mp4', 'class3')

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      # frame retrieval
      video_frames = self.frames_from_video_file(path, self.n_frames)
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
dataset_dir = pathlib.Path('/content/drive/MyDrive/AnwarSukoco/dataset_final/')

n_frames = 10

# banyaknya kelas
num_classes = len(FrameGeneration(dataset_dir / 'train', n_frames, training=True).class_names)

# %%
batch_size = 10

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGeneration(dataset_dir / 'train', n_frames, training=True),
                                          output_signature = output_signature)

# Batch data
train_ds = train_ds.batch(batch_size)

val_ds = tf.data.Dataset.from_generator(FrameGeneration(dataset_dir / 'val', n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)

test_ds = tf.data.Dataset.from_generator(FrameGeneration(dataset_dir / 'test', n_frames),
                                         output_signature = output_signature)

test_ds = test_ds.batch(batch_size)

# %%
input_shape = (batch_size, n_frames, HEIGHT, WIDTH, 3)

model = Sequential()

model.add(Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu", input_shape=input_shape[1:]))
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2, 2))))
model.add(Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2, 2))))
model.add(Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2, 2))))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2, 2))))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"))
model.add(TimeDistributed(MaxPool2D(pool_size=(2, 2), strides=(2, 2))))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(1024, return_sequences=False))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 10, 224, 224, 64   1792
#                              )
#
#  conv2d_1 (Conv2D)           (None, 10, 224, 224, 64   36928
#                              )
#
#  time_distributed (TimeDist  (None, 10, 112, 112, 64   0
#  ributed)                    )
#
#  conv2d_2 (Conv2D)           (None, 10, 112, 112, 12   73856
#                              8)
#
#  conv2d_3 (Conv2D)           (None, 10, 112, 112, 12   147584
#                              8)
#
#  time_distributed_1 (TimeDi  (None, 10, 56, 56, 128)   0
#  stributed)
#
#  conv2d_4 (Conv2D)           (None, 10, 56, 56, 256)   295168
#
#  conv2d_5 (Conv2D)           (None, 10, 56, 56, 256)   590080
#
#  conv2d_6 (Conv2D)           (None, 10, 56, 56, 256)   590080
#
#  time_distributed_2 (TimeDi  (None, 10, 28, 28, 256)   0
#  stributed)
#
#  conv2d_7 (Conv2D)           (None, 10, 28, 28, 512)   1180160
#
#  conv2d_8 (Conv2D)           (None, 10, 28, 28, 512)   2359808
#
#  conv2d_9 (Conv2D)           (None, 10, 28, 28, 512)   2359808
#
#  time_distributed_3 (TimeDi  (None, 10, 14, 14, 512)   0
#  stributed)
#
#  conv2d_10 (Conv2D)          (None, 10, 14, 14, 512)   2359808
#
#  conv2d_11 (Conv2D)          (None, 10, 14, 14, 512)   2359808
#
#  conv2d_12 (Conv2D)          (None, 10, 14, 14, 512)   2359808
#
#  time_distributed_4 (TimeDi  (None, 10, 7, 7, 512)     0
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 10, 25088)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 1024)              106958848
#
#  dense (Dense)               (None, 256)               262400
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 121969606 (465.28 MB)
# Trainable params: 121969606 (465.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.SGD(learning_rate = 0.0001),
              metrics = ['accuracy'])

# %%
model_save_path = "/content/drive/MyDrive/AnwarSukoco/TrainingHistory/model/konfigurasi_108_10_1024_150_0_0001"

checkpoint = tf.keras.callbacks.ModelCheckpoint(model_save_path+'/checkpoint_{epoch:02d}', save_freq='epoch')

csv_logger = tf.keras.callbacks.CSVLogger("/content/drive/MyDrive/AnwarSukoco/TrainingHistory/history/history108_10_1024_150_0_0001.csv", append=True)

# %%
history = model.fit(x = train_ds,
                    epochs = 150,
                    validation_data = val_ds,
                    callbacks = [checkpoint, csv_logger])
# Out:
# Epoch 1/150
# 12/12 [==============================] - 238s 18s/step - loss: 1.7918 - accuracy: 0.1667 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 2/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7918 - accuracy: 0.1750 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 3/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7918 - accuracy: 0.1750 - val_loss: 1.7918 - val_accuracy: 0.1333
# Epoch 4/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7918 - accuracy: 0.1750 - val_loss: 1.7918 - val_accuracy: 0.1333
# Epoch 5/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7918 - accuracy: 0.1917 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 6/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7918 - accuracy: 0.1833 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 7/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7917 - accuracy: 0.1750 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 8/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7918 - val_accuracy: 0.1667
# Epoch 9/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 10/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 11/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7917 - accuracy: 0.1750 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 12/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7917 - accuracy: 0.1750 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 13/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 14/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 15/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7917 - accuracy: 0.1750 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 16/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 17/150
# 12/12 [==============================] - 64s 6s/step - loss: 1.7917 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 18/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7917 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 19/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 20/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 21/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 22/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 23/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1750 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 24/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 25/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 26/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 27/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 28/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 29/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 30/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7917 - val_accuracy: 0.1667
# Epoch 31/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7916 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 32/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7916 - accuracy: 0.1750 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 33/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 34/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 35/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 36/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7916 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 37/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7915 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 38/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 39/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 40/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 41/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 42/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.2417 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 43/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.2167 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 44/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1667
# Epoch 45/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.2000 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 46/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.1833 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 47/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7915 - accuracy: 0.2333 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 48/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.2000 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 49/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7915 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 50/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.1917 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 51/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.2000 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 52/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7915 - accuracy: 0.2000 - val_loss: 1.7916 - val_accuracy: 0.1333
# Epoch 53/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7915 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 54/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7914 - accuracy: 0.2500 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 55/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 56/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 57/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 58/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.1833 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 59/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 60/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 61/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2250 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 62/150
# 12/12 [==============================] - 64s 6s/step - loss: 1.7914 - accuracy: 0.1833 - val_loss: 1.7915 - val_accuracy: 0.1667
# Epoch 63/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.2250 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 64/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 65/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 66/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2500 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 67/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2417 - val_loss: 1.7915 - val_accuracy: 0.1667
# Epoch 68/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7914 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 69/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7914 - accuracy: 0.2250 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 70/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.2083 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 71/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7914 - accuracy: 0.2250 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 72/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7914 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1667
# Epoch 73/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1667
# Epoch 74/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1667
# Epoch 75/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7914 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 76/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 77/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7914 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 78/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1000
# Epoch 79/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 80/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7914 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1000
# Epoch 81/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.1917 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 82/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1000
# Epoch 83/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 84/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2083 - val_loss: 1.7915 - val_accuracy: 0.1333
# Epoch 85/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7915 - val_accuracy: 0.1000
# Epoch 86/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2333 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 87/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 88/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 89/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2250 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 90/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 91/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7913 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 92/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 93/150
# 12/12 [==============================] - 66s 5s/step - loss: 1.7913 - accuracy: 0.1917 - val_loss: 1.7914 - val_accuracy: 0.1333
# Epoch 94/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1333
# Epoch 95/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 96/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7913 - accuracy: 0.1917 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 97/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 98/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.1833 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 99/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1333
# Epoch 100/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 101/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7913 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 102/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7913 - accuracy: 0.2250 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 103/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 104/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7912 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 105/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 106/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7912 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 107/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 108/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 109/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7912 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 110/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 111/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 112/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7912 - accuracy: 0.2167 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 113/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 114/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7914 - val_accuracy: 0.0667
# Epoch 115/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7914 - val_accuracy: 0.1000
# Epoch 116/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.1833 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 117/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7912 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 118/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7912 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 119/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7912 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 120/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 121/150
# 12/12 [==============================] - 64s 5s/step - loss: 1.7912 - accuracy: 0.1833 - val_loss: 1.7914 - val_accuracy: 0.1333
# Epoch 122/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.0667
# Epoch 123/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 124/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7912 - accuracy: 0.2083 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 125/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7912 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 126/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7912 - accuracy: 0.2417 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 127/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7912 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 128/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7912 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 129/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7912 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 130/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7912 - accuracy: 0.2167 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 131/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7911 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 132/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7911 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 133/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7911 - accuracy: 0.2250 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 134/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7912 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 135/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7911 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 136/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7911 - accuracy: 0.2000 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 137/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7911 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 138/150
# 12/12 [==============================] - 59s 5s/step - loss: 1.7911 - accuracy: 0.2250 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 139/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7911 - accuracy: 0.2417 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 140/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7911 - accuracy: 0.2500 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 141/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7911 - accuracy: 0.2250 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 142/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7911 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 143/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7911 - accuracy: 0.2167 - val_loss: 1.7913 - val_accuracy: 0.1333
# Epoch 144/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7911 - accuracy: 0.2250 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 145/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7911 - accuracy: 0.2083 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 146/150
# 12/12 [==============================] - 62s 5s/step - loss: 1.7911 - accuracy: 0.1917 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 147/150
# 12/12 [==============================] - 60s 5s/step - loss: 1.7911 - accuracy: 0.2083 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 148/150
# 12/12 [==============================] - 61s 5s/step - loss: 1.7911 - accuracy: 0.2167 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 149/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7911 - accuracy: 0.2333 - val_loss: 1.7913 - val_accuracy: 0.1000
# Epoch 150/150
# 12/12 [==============================] - 63s 5s/step - loss: 1.7911 - accuracy: 0.2083 - val_loss: 1.7913 - val_accuracy: 0.1000
