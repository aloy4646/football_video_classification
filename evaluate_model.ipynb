# %% [markdown]
# <a href="https://colab.research.google.com/github/aloy4646/football_video_classification/blob/main/evaluate_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tensorflow as tf
import random
import pathlib
import cv2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Evaluasi model

# %% [markdown]
# ### Load test data

# %%
HEIGHT = 224
WIDTH = 224

# %%
class FrameGeneration:
  def __init__(self, path, n_frames, training = False):
    """ Mengembalikan set frames beserta label terkait.

      Args:
        path: Path file video.
        n_frames: Jumlah frames.
        training: Boolean untuk menentukan apakah dataset training sedang dibuat.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    # video_paths = list(self.path.glob('*/*.avi'))
    video_paths = list(self.path.glob('*/*.mp4'))
    classes = [p.parent.name for p in video_paths]
    return video_paths, classes

  def frames_from_video_file(self, video_path, n_frames, output_size = (HEIGHT,WIDTH)):
    """
      Membuat frames dari setiap file video yang ada untuk setiap kategori.

      Args:
        video_path: Path file video.
        n_frames: Jumlah frames yang akan dibuat per file video.
        output_size: Ukuran piksel dari frame keluaran.

      Return:
        Array NumPy dari frames dengan bentuk (n_frames, HEIGHT, WIDTH, saluran).
    """
    # Read each video frame by frame
    result = []
    src = cv2.VideoCapture(str(video_path))

    video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

    # Frame step fleksibel mengikuti panjang dari sumber video
    frame_step = max(int(video_length / (n_frames-1)), 1)

    need_length = 1 + (n_frames-1) * frame_step

    if need_length > video_length:
      start = 0
    else:
      max_start = video_length - need_length
      start = random.randint(0, max_start + 1)

    src.set(cv2.CAP_PROP_POS_FRAMES, start)

    # ret is a boolean indicating whether read was successful, frame is the image itself
    ret, frame = src.read()
    result.append(self.format_frames(frame, output_size))

    for _ in range(n_frames - 1):
      for _ in range(frame_step):
        ret, frame = src.read()
      if ret and frame is not None:
        frame = self.format_frames(frame, output_size)
        result.append(frame)
      else:
        result.append(np.zeros_like(result[0]))

    src.release()
    result = np.array(result)[..., [2, 1, 0]]
    return result


  def format_frames(self, frame, output_size):
      """
      Menambahkan padding dan meresize frame dari video.

      Args:
          frame: frame yang perlu diresize dan dipad.
          output_size: Ukuran piksel dari frame keluaran.

          Return:
            Frame yang diformat dengan padding sesuai ukuran keluaran.
      """
      # return resized_frame
      frame = tf.image.convert_image_dtype(frame, tf.float32)
      frame = tf.image.resize_with_pad(frame, *output_size)
      return frame

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      # frame retrieval
      video_frames = self.frames_from_video_file(path, self.n_frames)
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label, path.name

# %%
dataset_dir = pathlib.Path('/content/drive/MyDrive/AnwarSukoco/dataset_final/')

n_frames = 10

# %%
batch_size = 1

# (n_frames, HEIGHT, WIDTH)
output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16),
                    tf.TensorSpec(shape = (), dtype = tf.string))

test_ds = tf.data.Dataset.from_generator(FrameGeneration(dataset_dir / 'test', n_frames),
                                         output_signature = output_signature)

test_ds = test_ds.batch(batch_size)

# %% [markdown]
# ### Evaluate

# %%
class Evaluate:
  def plot_confusion_matrix(actual, predicted, labels, konfiguration_number, path):
    cm = tf.math.confusion_matrix(actual, predicted)
    ax = sns.heatmap(cm, annot=True, fmt='g')
    sns.set(rc={'figure.figsize':(12, 12)})
    sns.set(font_scale=1.4)
    ax.set_title('Confusion matrix of model no. ' + str(konfiguration_number))
    ax.set_xlabel('Predicted Action')
    ax.set_ylabel('Actual Action')
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    ax.xaxis.set_ticklabels(labels)
    ax.yaxis.set_ticklabels(labels)
    plt.savefig(path, bbox_inches='tight')
    plt.close()
    plt.clf()

  def get_actual_predicted_labels(dataset, model):
    """
      Membuat daftar nilai ground truth aktual dan prediksi dari model.

      Args:
        dataset: Struktur data yang dapat diiterasi, seperti TensorFlow Dataset, dengan fitur dan label.

      Return:
        Nilai ground truth dan prediksi untuk dataset tertentu.
    """

    actual = []
    confidence = []
    predicted = []
    filenames = []

    for features, labels, filename in dataset.unbatch():
        actual.append(labels)

        # Features adalah 10 frame yang dianggap menjadi 1 video
        reshaped_features = tf.expand_dims(features, axis=0)
        prediction = model.predict(reshaped_features, verbose=0)
        predicted_classes = tf.argmax(prediction, axis=1).numpy()[0]
        predicted.append(predicted_classes)
        confidence.append(prediction[0])
        filenames.append(filename.numpy().decode())

    actual = tf.stack(actual, axis=0)
    predicted = tf.stack(predicted, axis=0)
    confidence = tf.constant(confidence)

    return actual, confidence, predicted, filenames

  def calculate_classification_metrics(y_actual, y_pred, labels):
    """
    Menghitung precision, recall, dan F1 score dari model klasifikasi menggunakan nilai ground truth dan
    prediksi.

    Args:
      y_actual: Label ground truth.
      y_pred: Label prediksi.
      labels: Daftar label klasifikasi.

    Return:
      Ukuran precision, recall, dan F1 score.
    """
    cm = tf.math.confusion_matrix(y_actual, y_pred)
    tp = np.diag(cm)  # Diagonal mewakili true positives
    precision = dict()
    recall = dict()
    f1_score = dict()

    for i in range(len(labels)):
        col = cm[:, i]
        row = cm[i, :]

        fp = np.sum(col) - tp[i]  # Jumlah kolom minus true positive adalah false positif
        fn = np.sum(row) - tp[i]   # Jumlah baris minus true positive adalah false negative

        precision[labels[i]] = tp[i] / (tp[i] + fp) if (tp[i] + fp) != 0 else 0  # Precision
        recall[labels[i]] = tp[i] / (tp[i] + fn) if (tp[i] + fn) != 0 else 0  # Recall

        # Calculate F1 score
        f1_score[labels[i]] = 2 * (precision[labels[i]] * recall[labels[i]]) / \
                              (precision[labels[i]] + recall[labels[i]]) if \
                              (precision[labels[i]] + recall[labels[i]]) != 0 else 0

    accuracy = np.sum(tp) / np.sum(cm)  # Accuracy

    mean_precision = np.mean(list(precision.values()))
    mean_recall = np.mean(list(recall.values()))
    mean_f1_score = np.mean(list(f1_score.values()))

    return accuracy, precision, recall, f1_score, mean_precision, mean_recall, mean_f1_score

  def simpan_hasil_prediksi_per_video(actual, confidence, predicted, filename, nomor_model):
    arr_actual = actual.numpy()
    arr_confidence = confidence.numpy()
    arr_predicted = predicted.numpy()

    csv_hasil_prediksi = []

    for i in range(len(filename)):
      formatted_confidence = ["{:.10f}".format(val) for val in arr_confidence[i]]
      csv_hasil_prediksi.append({
          "Filename": filename[i],
          "Actual":arr_actual[i],
          "Predicted":arr_predicted[i],
          "Confidence[0]":formatted_confidence[0],
          "Confidence[1]":formatted_confidence[1],
          "Confidence[2]":formatted_confidence[2],
          "Confidence[3]":formatted_confidence[3],
          "Confidence[4]":formatted_confidence[4],
          "Confidence[5]":formatted_confidence[5]
      })

      df_hasil_prediksi = pd.DataFrame(csv_hasil_prediksi)

      csv_path = "/content/drive/MyDrive/AnwarSukoco/csv_pengujian/pengujian_per_file/model_" + str(nomor_model) + ".csv"
      df_hasil_prediksi.to_csv(csv_path, index=False)

# %%
fg = FrameGeneration(dataset_dir / 'test', n_frames)
labels = list(fg.class_ids_for_name.keys())

# %%
directory = "/content/drive/MyDrive/AnwarSukoco/hasil_pelatihan"
directory_gambar_confusion_matrix = "/content/drive/MyDrive/AnwarSukoco/gambar_confusion_matrix"
csv_akurasi = []
csv_precision = []
csv_recall = []
csv_f1_score = []

for konfigurasi_folder in sorted(os.listdir(directory)):
    konfigurasi_path = os.path.join(directory, konfigurasi_folder)

    # Periksa apakah itu adalah folder
    if os.path.isdir(konfigurasi_path):
        print("==========================================")
        print(f"Mengolah folder konfigurasi: {konfigurasi_folder}")
        model_path = os.path.join(konfigurasi_path, "model")

        for checkpoint_folder in sorted(os.listdir(model_path)):
          print(f"---Mengolah folder checkpoint: {checkpoint_folder}")
          checkpoint_path = os.path.join(model_path, checkpoint_folder)

          # load dan menguji model
          model = tf.keras.models.load_model(checkpoint_path)

          actual, confidence, predicted, filenames = Evaluate.get_actual_predicted_labels(test_ds, model)

          # plot confusion matrix setiap model
          plt.clf()
          path_confusion_matrix = os.path.join(directory_gambar_confusion_matrix, checkpoint_folder)
          # mengambil nomor model
          nomor_model = ''.join(filter(str.isdigit, checkpoint_folder))
          Evaluate.plot_confusion_matrix(actual, predicted, labels, int(nomor_model), path_confusion_matrix)

          Evaluate.simpan_hasil_prediksi_per_video(actual, confidence, predicted, filenames, nomor_model)

          # # menghitung precision, recall, dan f1_score
          accuracy, precision, recall, f1_score, mean_precision, mean_recall, mean_f1_score = Evaluate.calculate_classification_metrics(actual,
                                                                                                                                        predicted,
                                                                                                                                        labels)

          csv_akurasi.append({
              "Nomor model": nomor_model,
              "Akurasi": accuracy
          })

          csv_precision.append({
              "Nomor model": nomor_model,
              "Card": precision['card'],
              "Celebration": precision['celebration'],
              "Corner": precision['corner'],
              "Foul": precision['foul'],
              "Shot": precision['shot'],
              "Substitution": precision['substitution'],
              "Average": mean_precision
          })

          csv_recall.append({
              "Nomor model": nomor_model,
              "Card": recall['card'],
              "Celebration": recall['celebration'],
              "Corner": recall['corner'],
              "Foul": recall['foul'],
              "Shot": recall['shot'],
              "Substitution": recall['substitution'],
              "Average": mean_recall
          })

          csv_f1_score.append({
              "Nomor model": nomor_model,
              "Card": f1_score['card'],
              "Celebration": f1_score['celebration'],
              "Corner": f1_score['corner'],
              "Foul": f1_score['foul'],
              "Shot": f1_score['shot'],
              "Substitution": f1_score['substitution'],
              "Average": mean_f1_score
          })

          print("------Accuracy: " + str(accuracy))
          print("------Precision: " + str(precision))
          print("------Mean Precision: " + str(mean_precision))
          print("------Recall: " + str(recall))
          print("------Mean Recall: " + str(mean_recall))
          print("------f1 score: " + str(f1_score))
          print("------Mean f1 score: " + str(mean_f1_score))

df_akurasi = pd.DataFrame(csv_akurasi)
df_precision = pd.DataFrame(csv_precision)
df_recall = pd.DataFrame(csv_recall)
df_f1_score = pd.DataFrame(csv_f1_score)

# Menyimpan DataFrame sebagai file CSV
csv_path = "/content/drive/MyDrive/AnwarSukoco/csv_pengujian/"
df_akurasi.to_csv(csv_path+"akurasi.csv", index=False)
df_precision.to_csv(csv_path+"precision.csv", index=False)
df_recall.to_csv(csv_path+"recall.csv", index=False)
df_f1_score.to_csv(csv_path+"f1_score.csv", index=False)
# Out:
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_1-4-7_10
# ---Mengolah folder checkpoint: checkpoint_1
# ------Accuracy: 0.5666666666666667
# ------Precision: {'card': 0.0, 'celebration': 0, 'corner': 0.4166666666666667, 'foul': 0.8333333333333334, 'shot': 1.0, 'substitution': 1.0}
# ------Mean Precision: 0.5416666666666666
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Recall: 0.5666666666666667
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.5882352941176471, 'foul': 0.9090909090909091, 'shot': 1.0, 'substitution': 0.5714285714285715}
# ------Mean f1 score: 0.511459129106188
# ---Mengolah folder checkpoint: checkpoint_10
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.8, 'celebration': 0.0, 'corner': 0.8333333333333334, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Precision: 0.6246031746031746
# ------Recall: {'card': 0.8, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.8000000000000002, 'celebration': 0, 'corner': 0.9090909090909091, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4000000000000001}
# ------Mean f1 score: 0.6385521885521885
# ---Mengolah folder checkpoint: checkpoint_4
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 1.0, 'celebration': 0.4, 'corner': 0.7142857142857143, 'foul': 0.5555555555555556, 'shot': 0.75, 'substitution': 0.6666666666666666}
# ------Mean Precision: 0.6810846560846562
# ------Recall: {'card': 0.4, 'celebration': 0.4, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333333
# ------f1 score: {'card': 0.5714285714285715, 'celebration': 0.4000000000000001, 'corner': 0.8333333333333333, 'foul': 0.7142857142857143, 'shot': 0.6666666666666665, 'substitution': 0.5}
# ------Mean f1 score: 0.6142857142857142
# ---Mengolah folder checkpoint: checkpoint_7
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.75, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Precision: 0.5964285714285714
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333334
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4000000000000001}
# ------Mean f1 score: 0.6037037037037036
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_13-16-19-22
# ---Mengolah folder checkpoint: checkpoint_13
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0.5, 'corner': 1.0, 'foul': 1.0, 'shot': 0.4166666666666667, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.5416666666666666
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.2, 'foul': 0.6, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0, 'celebration': 0.6153846153846154, 'corner': 0.33333333333333337, 'foul': 0.7499999999999999, 'shot': 0.5882352941176471, 'substitution': 0.3636363636363636}
# ------Mean f1 score: 0.4417649344119932
# ---Mengolah folder checkpoint: checkpoint_16
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.5, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.75}
# ------Mean Precision: 0.6130952380952381
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.6}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.5454545454545454, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.6666666666666665}
# ------Mean f1 score: 0.6279461279461279
# ---Mengolah folder checkpoint: checkpoint_19
# ------Accuracy: 0.6
# ------Precision: {'card': 0.375, 'celebration': 0, 'corner': 0.7142857142857143, 'foul': 0.5555555555555556, 'shot': 1.0, 'substitution': 0.75}
# ------Mean Precision: 0.5658068783068783
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.4, 'substitution': 0.6}
# ------Mean Recall: 0.6
# ------f1 score: {'card': 0.4615384615384615, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.7142857142857143, 'shot': 0.5714285714285715, 'substitution': 0.6666666666666665}
# ------Mean f1 score: 0.5412087912087912
# ---Mengolah folder checkpoint: checkpoint_22
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.42857142857142855, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.75}
# ------Mean Precision: 0.6011904761904762
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.6}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.5, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.6666666666666665}
# ------Mean f1 score: 0.6203703703703703
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_14-17-20-23
# ---Mengolah folder checkpoint: checkpoint_14
# ------Accuracy: 0.2
# ------Precision: {'card': 0, 'celebration': 0.16666666666666666, 'corner': 0.0, 'foul': 0, 'shot': 0, 'substitution': 0.26666666666666666}
# ------Mean Precision: 0.07222222222222223
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.8}
# ------Mean Recall: 0.20000000000000004
# ------f1 score: {'card': 0, 'celebration': 0.23529411764705882, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.4}
# ------Mean f1 score: 0.10588235294117647
# ---Mengolah folder checkpoint: checkpoint_17
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 0, 'celebration': 0.21739130434782608, 'corner': 0.0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.4528985507246377
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.2, 'shot': 0.6, 'substitution': 0.2}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.3571428571428571, 'corner': 0, 'foul': 0.33333333333333337, 'shot': 0.7499999999999999, 'substitution': 0.28571428571428575}
# ------Mean f1 score: 0.2876984126984127
# ---Mengolah folder checkpoint: checkpoint_20
# ------Accuracy: 0.43333333333333335
# ------Precision: {'card': 0, 'celebration': 0.4, 'corner': 0.0, 'foul': 0.6, 'shot': 0.75, 'substitution': 0.3}
# ------Mean Precision: 0.3416666666666666
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.6, 'shot': 0.6, 'substitution': 0.6}
# ------Mean Recall: 0.43333333333333335
# ------f1 score: {'card': 0, 'celebration': 0.5333333333333333, 'corner': 0, 'foul': 0.6, 'shot': 0.6666666666666665, 'substitution': 0.4}
# ------Mean f1 score: 0.36666666666666664
# ---Mengolah folder checkpoint: checkpoint_23
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0.5714285714285714, 'corner': 0.3333333333333333, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.25}
# ------Mean Precision: 0.4924603174603175
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.2, 'foul': 0.6, 'shot': 0.8, 'substitution': 0.6}
# ------Mean Recall: 0.5000000000000001
# ------f1 score: {'card': 0, 'celebration': 0.6666666666666666, 'corner': 0.25, 'foul': 0.7499999999999999, 'shot': 0.8000000000000002, 'substitution': 0.35294117647058826}
# ------Mean f1 score: 0.46993464052287587
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_15-18-21-24
# ---Mengolah folder checkpoint: checkpoint_15
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.16666666666666666}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.2857142857142857}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_18
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.16666666666666666}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.2857142857142857}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_21
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.16666666666666666}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.2857142857142857}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_24
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 1.0, 'substitution': 0.17857142857142858}
# ------Mean Precision: 0.19642857142857142
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.4, 'substitution': 1.0}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0.5714285714285715, 'substitution': 0.30303030303030304}
# ------Mean f1 score: 0.14574314574314576
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_2-5-8-11
# ---Mengolah folder checkpoint: checkpoint_11
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.8333333333333334, 'foul': 0.625, 'shot': 0.8, 'substitution': 0.45454545454545453}
# ------Mean Precision: 0.45214646464646474
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 1.0}
# ------Mean Recall: 0.6333333333333333
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.9090909090909091, 'foul': 0.7692307692307693, 'shot': 0.8000000000000002, 'substitution': 0.625}
# ------Mean f1 score: 0.5172202797202797
# ---Mengolah folder checkpoint: checkpoint_2
# ------Accuracy: 0.4
# ------Precision: {'card': 0, 'celebration': 0.6666666666666666, 'corner': 0.4444444444444444, 'foul': 0.29411764705882354, 'shot': 0, 'substitution': 1.0}
# ------Mean Precision: 0.40087145969498916
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.8, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.2}
# ------Mean Recall: 0.4000000000000001
# ------f1 score: {'card': 0, 'celebration': 0.5, 'corner': 0.5714285714285714, 'foul': 0.45454545454545453, 'shot': 0, 'substitution': 0.33333333333333337}
# ------Mean f1 score: 0.3098845598845599
# ---Mengolah folder checkpoint: checkpoint_5
# ------Accuracy: 0.5333333333333333
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.7142857142857143, 'foul': 0.5, 'shot': 0.5, 'substitution': 0.45454545454545453}
# ------Mean Precision: 0.3614718614718615
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.2, 'substitution': 1.0}
# ------Mean Recall: 0.5333333333333333
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.6666666666666666, 'shot': 0.28571428571428575, 'substitution': 0.625}
# ------Mean f1 score: 0.40178571428571425
# ---Mengolah folder checkpoint: checkpoint_8
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 1.0, 'foul': 0.38461538461538464, 'shot': 0.2, 'substitution': 0.625}
# ------Mean Precision: 0.36826923076923074
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.8, 'foul': 1.0, 'shot': 0.2, 'substitution': 1.0}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.888888888888889, 'foul': 0.5555555555555556, 'shot': 0.20000000000000004, 'substitution': 0.7692307692307693}
# ------Mean f1 score: 0.40227920227920233
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_25-28-31-34
# ---Mengolah folder checkpoint: checkpoint_25
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 0, 'celebration': 0.29411764705882354, 'corner': 0, 'foul': 0, 'shot': 0.38461538461538464, 'substitution': 0}
# ------Mean Precision: 0.11312217194570136
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.45454545454545453, 'corner': 0, 'foul': 0, 'shot': 0.5555555555555556, 'substitution': 0}
# ------Mean f1 score: 0.16835016835016836
# ---Mengolah folder checkpoint: checkpoint_28
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.75, 'celebration': 0.3333333333333333, 'corner': 0.7142857142857143, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.6}
# ------Mean Precision: 0.6704365079365079
# ------Recall: {'card': 0.6, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.6}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0.25, 'corner': 0.8333333333333333, 'foul': 0.7692307692307693, 'shot': 0.7499999999999999, 'substitution': 0.6}
# ------Mean f1 score: 0.6448717948717949
# ---Mengolah folder checkpoint: checkpoint_31
# ------Accuracy: 0.7666666666666667
# ------Precision: {'card': 1.0, 'celebration': 0.5, 'corner': 1.0, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.7857142857142857
# ------Recall: {'card': 0.8, 'celebration': 0.4, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.6}
# ------Mean Recall: 0.7666666666666666
# ------f1 score: {'card': 0.888888888888889, 'celebration': 0.4444444444444445, 'corner': 1.0, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.766835016835017
# ---Mengolah folder checkpoint: checkpoint_34
# ------Accuracy: 0.7333333333333333
# ------Precision: {'card': 1.0, 'celebration': 0.3333333333333333, 'corner': 0.8333333333333334, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.7301587301587302
# ------Recall: {'card': 0.8, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.6}
# ------Mean Recall: 0.7333333333333333
# ------f1 score: {'card': 0.888888888888889, 'celebration': 0.25, 'corner': 0.9090909090909091, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.7192760942760943
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_26-29-32-35
# ---Mengolah folder checkpoint: checkpoint_26
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.4, 'foul': 0.6, 'shot': 0.5, 'substitution': 0.5714285714285714}
# ------Mean Precision: 0.3452380952380952
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.8, 'foul': 0.6, 'shot': 0.8, 'substitution': 0.8}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.5333333333333333, 'foul': 0.6, 'shot': 0.6153846153846154, 'substitution': 0.6666666666666666}
# ------Mean f1 score: 0.4025641025641025
# ---Mengolah folder checkpoint: checkpoint_29
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0.75, 'corner': 0.5, 'foul': 0.6, 'shot': 0.3125, 'substitution': 1.0}
# ------Mean Precision: 0.5270833333333333
# ------Recall: {'card': 0.0, 'celebration': 0.6, 'corner': 0.2, 'foul': 0.6, 'shot': 1.0, 'substitution': 0.6}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0, 'celebration': 0.6666666666666665, 'corner': 0.28571428571428575, 'foul': 0.6, 'shot': 0.47619047619047616, 'substitution': 0.7499999999999999}
# ------Mean f1 score: 0.46309523809523806
# ---Mengolah folder checkpoint: checkpoint_32
# ------Accuracy: 0.5666666666666667
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.6666666666666666, 'foul': 0.6, 'shot': 0.5, 'substitution': 0.5555555555555556}
# ------Mean Precision: 0.387037037037037
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.8, 'foul': 0.6, 'shot': 1.0, 'substitution': 1.0}
# ------Mean Recall: 0.5666666666666667
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.7272727272727272, 'foul': 0.6, 'shot': 0.6666666666666666, 'substitution': 0.7142857142857143}
# ------Mean f1 score: 0.45137085137085137
# ---Mengolah folder checkpoint: checkpoint_35
# ------Accuracy: 0.5
# ------Precision: {'card': 1.0, 'celebration': 0, 'corner': 1.0, 'foul': 0.6, 'shot': 0.5, 'substitution': 0.38461538461538464}
# ------Mean Precision: 0.5807692307692308
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 0.2, 'foul': 0.6, 'shot': 1.0, 'substitution': 1.0}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0.33333333333333337, 'celebration': 0, 'corner': 0.33333333333333337, 'foul': 0.6, 'shot': 0.6666666666666666, 'substitution': 0.5555555555555556}
# ------Mean f1 score: 0.4148148148148148
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_27-30-33-36
# ---Mengolah folder checkpoint: checkpoint_27
# ------Accuracy: 0.2
# ------Precision: {'card': 0.14285714285714285, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.21739130434782608}
# ------Mean Precision: 0.060041407867494824
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.19999999999999998
# ------f1 score: {'card': 0.16666666666666666, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.3571428571428571}
# ------Mean f1 score: 0.08730158730158728
# ---Mengolah folder checkpoint: checkpoint_30
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0.23076923076923078, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.29411764705882354}
# ------Mean Precision: 0.08748114630467572
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0.33333333333333337, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.45454545454545453}
# ------Mean f1 score: 0.1313131313131313
# ---Mengolah folder checkpoint: checkpoint_33
# ------Accuracy: 0.3
# ------Precision: {'card': 0.26666666666666666, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.09999999999999999
# ------Recall: {'card': 0.8, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0.4, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5}
# ------Mean f1 score: 0.15
# ---Mengolah folder checkpoint: checkpoint_36
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 0.29411764705882354, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.38461538461538464}
# ------Mean Precision: 0.11312217194570136
# ------Recall: {'card': 1.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0.45454545454545453, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5555555555555556}
# ------Mean f1 score: 0.16835016835016836
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_3-6-9-12
# ---Mengolah folder checkpoint: checkpoint_12
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0.4, 'celebration': 0.16666666666666666, 'corner': 1.0, 'foul': 1.0, 'shot': 0.3125, 'substitution': 0}
# ------Mean Precision: 0.47986111111111107
# ------Recall: {'card': 0.4, 'celebration': 0.2, 'corner': 0.4, 'foul': 0.2, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0.4000000000000001, 'celebration': 0.1818181818181818, 'corner': 0.5714285714285715, 'foul': 0.33333333333333337, 'shot': 0.47619047619047616, 'substitution': 0}
# ------Mean f1 score: 0.32712842712842716
# ---Mengolah folder checkpoint: checkpoint_3
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0.16666666666666666, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0.2857142857142857, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_6
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0.25, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.21739130434782608, 'substitution': 0}
# ------Mean Precision: 0.411231884057971
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 0.2, 'foul': 0.2, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0.22222222222222224, 'celebration': 0, 'corner': 0.33333333333333337, 'foul': 0.33333333333333337, 'shot': 0.3571428571428571, 'substitution': 0}
# ------Mean f1 score: 0.20767195767195767
# ---Mengolah folder checkpoint: checkpoint_9
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 0.25, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.25, 'substitution': 0}
# ------Mean Precision: 0.4166666666666667
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 0.4, 'foul': 0.4, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0.22222222222222224, 'celebration': 0, 'corner': 0.5714285714285715, 'foul': 0.5714285714285715, 'shot': 0.4, 'substitution': 0}
# ------Mean f1 score: 0.29417989417989415
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_37-40-43-46
# ---Mengolah folder checkpoint: checkpoint_37
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0.20833333333333334, 'substitution': 0.5}
# ------Mean Precision: 0.11805555555555557
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.6}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0.3448275862068966, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.148380355276907
# ---Mengolah folder checkpoint: checkpoint_40
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.75, 'celebration': 0.4, 'corner': 0.8333333333333334, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0}
# ------Mean Precision: 0.6162698412698413
# ------Recall: {'card': 0.6, 'celebration': 0.8, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.0}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0.5333333333333333, 'corner': 0.9090909090909091, 'foul': 0.8333333333333333, 'shot': 0.7499999999999999, 'substitution': 0}
# ------Mean f1 score: 0.6154040404040404
# ---Mengolah folder checkpoint: checkpoint_43
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.5, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Precision: 0.6023809523809524
# ------Recall: {'card': 0.8, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.6153846153846154, 'celebration': 0, 'corner': 1.0, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4000000000000001}
# ------Mean f1 score: 0.6229344729344729
# ---Mengolah folder checkpoint: checkpoint_46
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.5, 'celebration': 0.5, 'corner': 0.8333333333333334, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.6597222222222222
# ------Recall: {'card': 0.8, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.4, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333333
# ------f1 score: {'card': 0.6153846153846154, 'celebration': 0.28571428571428575, 'corner': 0.9090909090909091, 'foul': 0.7692307692307693, 'shot': 0.5714285714285715, 'substitution': 0.4444444444444445}
# ------Mean f1 score: 0.5992155992155993
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_38-41-44-47
# ---Mengolah folder checkpoint: checkpoint_38
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 1.0, 'foul': 0, 'shot': 0.25, 'substitution': 0.5555555555555556}
# ------Mean Precision: 0.30092592592592593
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.2, 'foul': 0.0, 'shot': 1.0, 'substitution': 1.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.33333333333333337, 'foul': 0, 'shot': 0.4, 'substitution': 0.7142857142857143}
# ------Mean f1 score: 0.2412698412698413
# ---Mengolah folder checkpoint: checkpoint_41
# ------Accuracy: 0.4666666666666667
# ------Precision: {'card': 0, 'celebration': 0.5714285714285714, 'corner': 1.0, 'foul': 0, 'shot': 0.29411764705882354, 'substitution': 0.6666666666666666}
# ------Mean Precision: 0.42203548085901027
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.6, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Recall: 0.4666666666666666
# ------f1 score: {'card': 0, 'celebration': 0.6666666666666666, 'corner': 0.7499999999999999, 'foul': 0, 'shot': 0.45454545454545453, 'substitution': 0.5}
# ------Mean f1 score: 0.39520202020202017
# ---Mengolah folder checkpoint: checkpoint_44
# ------Accuracy: 0.5
# ------Precision: {'card': 0, 'celebration': 0.75, 'corner': 1.0, 'foul': 0, 'shot': 0.29411764705882354, 'substitution': 0.6666666666666666}
# ------Mean Precision: 0.451797385620915
# ------Recall: {'card': 0.0, 'celebration': 0.6, 'corner': 0.6, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.8}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0, 'celebration': 0.6666666666666665, 'corner': 0.7499999999999999, 'foul': 0, 'shot': 0.45454545454545453, 'substitution': 0.7272727272727272}
# ------Mean f1 score: 0.433080808080808
# ---Mengolah folder checkpoint: checkpoint_47
# ------Accuracy: 0.4666666666666667
# ------Precision: {'card': 0, 'celebration': 0.4444444444444444, 'corner': 1.0, 'foul': 0, 'shot': 0.3333333333333333, 'substitution': 0.5}
# ------Mean Precision: 0.3796296296296296
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.8, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.2}
# ------Mean Recall: 0.46666666666666673
# ------f1 score: {'card': 0, 'celebration': 0.5714285714285714, 'corner': 0.888888888888889, 'foul': 0, 'shot': 0.5, 'substitution': 0.28571428571428575}
# ------Mean f1 score: 0.37433862433862436
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_39-42-45-48
# ---Mengolah folder checkpoint: checkpoint_39
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0.25, 'celebration': 0.14285714285714285, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.4166666666666667}
# ------Mean Precision: 0.1349206349206349
# ------Recall: {'card': 0.2, 'celebration': 0.4, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0.22222222222222224, 'celebration': 0.21052631578947364, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5882352941176471}
# ------Mean f1 score: 0.17016397202155717
# ---Mengolah folder checkpoint: checkpoint_42
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0.25, 'celebration': 0.15, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5}
# ------Mean Precision: 0.15
# ------Recall: {'card': 0.2, 'celebration': 0.6, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.6}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0.22222222222222224, 'celebration': 0.24, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.16794612794612793
# ---Mengolah folder checkpoint: checkpoint_45
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0, 'celebration': 0.2, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.3}
# ------Mean Precision: 0.08333333333333333
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.6}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.32000000000000006, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.4}
# ------Mean f1 score: 0.12000000000000001
# ---Mengolah folder checkpoint: checkpoint_48
# ------Accuracy: 0.3
# ------Precision: {'card': 0, 'celebration': 0.23529411764705882, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.38461538461538464}
# ------Mean Precision: 0.10331825037707391
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0, 'celebration': 0.3636363636363636, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.5555555555555556}
# ------Mean f1 score: 0.1531986531986532
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_49-52-55-58
# ---Mengolah folder checkpoint: checkpoint_49
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.16666666666666666, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.2857142857142857, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_52
# ------Accuracy: 0.3
# ------Precision: {'card': 0.125, 'celebration': 0, 'corner': 0, 'foul': 0.5, 'shot': 0.4, 'substitution': 1.0}
# ------Mean Precision: 0.33749999999999997
# ------Recall: {'card': 0.4, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.8, 'shot': 0.4, 'substitution': 0.2}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0.19047619047619047, 'celebration': 0, 'corner': 0, 'foul': 0.6153846153846154, 'shot': 0.4000000000000001, 'substitution': 0.33333333333333337}
# ------Mean f1 score: 0.25653235653235656
# ---Mengolah folder checkpoint: checkpoint_55
# ------Accuracy: 0.5333333333333333
# ------Precision: {'card': 0.5, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.625, 'shot': 0.6666666666666666, 'substitution': 0.375}
# ------Mean Precision: 0.4801587301587302
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.4, 'substitution': 0.6}
# ------Mean Recall: 0.5333333333333333
# ------f1 score: {'card': 0.28571428571428575, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.7692307692307693, 'shot': 0.5, 'substitution': 0.4615384615384615}
# ------Mean f1 score: 0.474969474969475
# ---Mengolah folder checkpoint: checkpoint_58
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.75, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Precision: 0.5964285714285714
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333334
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4000000000000001}
# ------Mean f1 score: 0.6037037037037036
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_50-53-56-59
# ---Mengolah folder checkpoint: checkpoint_50
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0, 'celebration': 0.2631578947368421, 'corner': 0.18181818181818182, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.07416267942583732
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.4, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.4166666666666667, 'corner': 0.25000000000000006, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.11111111111111112
# ---Mengolah folder checkpoint: checkpoint_53
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0, 'celebration': 0.3125, 'corner': 1.0, 'foul': 0, 'shot': 0.38461538461538464, 'substitution': 0}
# ------Mean Precision: 0.2828525641025641
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.2, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0, 'celebration': 0.47619047619047616, 'corner': 0.33333333333333337, 'foul': 0, 'shot': 0.5555555555555556, 'substitution': 0}
# ------Mean f1 score: 0.22751322751322753
# ---Mengolah folder checkpoint: checkpoint_56
# ------Accuracy: 0.5
# ------Precision: {'card': 0.5, 'celebration': 0.3125, 'corner': 1.0, 'foul': 0.75, 'shot': 1.0, 'substitution': 0}
# ------Mean Precision: 0.59375
# ------Recall: {'card': 0.6, 'celebration': 1.0, 'corner': 0.2, 'foul': 0.6, 'shot': 0.6, 'substitution': 0.0}
# ------Mean Recall: 0.5
# ------f1 score: {'card': 0.5454545454545454, 'celebration': 0.47619047619047616, 'corner': 0.33333333333333337, 'foul': 0.6666666666666665, 'shot': 0.7499999999999999, 'substitution': 0}
# ------Mean f1 score: 0.46194083694083693
# ---Mengolah folder checkpoint: checkpoint_59
# ------Accuracy: 0.43333333333333335
# ------Precision: {'card': 0.36363636363636365, 'celebration': 0.35714285714285715, 'corner': 0, 'foul': 1.0, 'shot': 0.5, 'substitution': 0}
# ------Mean Precision: 0.37012987012987014
# ------Recall: {'card': 0.8, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.6, 'shot': 0.2, 'substitution': 0.0}
# ------Mean Recall: 0.43333333333333335
# ------f1 score: {'card': 0.5000000000000001, 'celebration': 0.5263157894736842, 'corner': 0, 'foul': 0.7499999999999999, 'shot': 0.28571428571428575, 'substitution': 0}
# ------Mean f1 score: 0.34367167919799496
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_51-54-57-60
# ---Mengolah folder checkpoint: checkpoint_51
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0.16666666666666666, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 1.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0.2857142857142857, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_54
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0.18518518518518517, 'celebration': 0, 'corner': 0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0}
# ------Mean Precision: 0.36419753086419754
# ------Recall: {'card': 1.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.4, 'shot': 0.2, 'substitution': 0.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0.3125, 'celebration': 0, 'corner': 0, 'foul': 0.5714285714285715, 'shot': 0.33333333333333337, 'substitution': 0}
# ------Mean f1 score: 0.20287698412698416
# ---Mengolah folder checkpoint: checkpoint_57
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0.16666666666666666, 'celebration': 0, 'corner': 0, 'foul': 0.75, 'shot': 0.5, 'substitution': 0}
# ------Mean Precision: 0.23611111111111108
# ------Recall: {'card': 0.8, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.6, 'shot': 0.2, 'substitution': 0.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0.27586206896551724, 'celebration': 0, 'corner': 0, 'foul': 0.6666666666666665, 'shot': 0.28571428571428575, 'substitution': 0}
# ------Mean f1 score: 0.20470717022441157
# ---Mengolah folder checkpoint: checkpoint_60
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 0.15789473684210525, 'celebration': 0, 'corner': 0, 'foul': 0.75, 'shot': 0.5714285714285714, 'substitution': 0}
# ------Mean Precision: 0.24655388471177944
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.6, 'shot': 0.8, 'substitution': 0.0}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0.25, 'celebration': 0, 'corner': 0, 'foul': 0.6666666666666665, 'shot': 0.6666666666666666, 'substitution': 0}
# ------Mean f1 score: 0.26388888888888884
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_61-64-67-70
# ---Mengolah folder checkpoint: checkpoint_61
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.0, 'foul': 0, 'shot': 0, 'substitution': 0.2}
# ------Mean Precision: 0.03333333333333333
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 1.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0.33333333333333337}
# ------Mean f1 score: 0.05555555555555556
# ---Mengolah folder checkpoint: checkpoint_64
# ------Accuracy: 0.5666666666666667
# ------Precision: {'card': 0.6666666666666666, 'celebration': 0.0, 'corner': 0.5, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.6666666666666666}
# ------Mean Precision: 0.5763888888888888
# ------Recall: {'card': 0.4, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.4}
# ------Mean Recall: 0.5666666666666667
# ------f1 score: {'card': 0.5, 'celebration': 0, 'corner': 0.6666666666666666, 'foul': 0.7692307692307693, 'shot': 0.7499999999999999, 'substitution': 0.5}
# ------Mean f1 score: 0.530982905982906
# ---Mengolah folder checkpoint: checkpoint_67
# ------Accuracy: 0.7
# ------Precision: {'card': 0.8, 'celebration': 0.3333333333333333, 'corner': 1.0, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.7097222222222221
# ------Recall: {'card': 0.8, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.6}
# ------Mean Recall: 0.7000000000000001
# ------f1 score: {'card': 0.8000000000000002, 'celebration': 0.25, 'corner': 1.0, 'foul': 0.7692307692307693, 'shot': 0.7499999999999999, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.6857808857808858
# ---Mengolah folder checkpoint: checkpoint_70
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.75, 'celebration': 0.25, 'corner': 0.7142857142857143, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.6398809523809524
# ------Recall: {'card': 0.6, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333333
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0.22222222222222224, 'corner': 0.8333333333333333, 'foul': 0.7692307692307693, 'shot': 0.7499999999999999, 'substitution': 0.4444444444444445}
# ------Mean f1 score: 0.6143162393162392
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_62-65-68-71
# ---Mengolah folder checkpoint: checkpoint_62
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0.17647058823529413, 'corner': 0.16666666666666666, 'foul': 0, 'shot': 0, 'substitution': 0.14285714285714285}
# ------Mean Precision: 0.08099906629318394
# ------Recall: {'card': 0.0, 'celebration': 0.6, 'corner': 0.2, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.2}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0.2727272727272727, 'corner': 0.1818181818181818, 'foul': 0, 'shot': 0, 'substitution': 0.16666666666666666}
# ------Mean f1 score: 0.10353535353535352
# ---Mengolah folder checkpoint: checkpoint_65
# ------Accuracy: 0.2
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.18518518518518517, 'foul': 0, 'shot': 0, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.08641975308641975
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.2}
# ------Mean Recall: 0.19999999999999998
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3125, 'foul': 0, 'shot': 0, 'substitution': 0.25}
# ------Mean f1 score: 0.09375
# ---Mengolah folder checkpoint: checkpoint_68
# ------Accuracy: 0.4666666666666667
# ------Precision: {'card': 0, 'celebration': 0.375, 'corner': 0.3, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.6666666666666666}
# ------Mean Precision: 0.4944444444444444
# ------Recall: {'card': 0.0, 'celebration': 0.6, 'corner': 0.6, 'foul': 1.0, 'shot': 0.2, 'substitution': 0.4}
# ------Mean Recall: 0.46666666666666673
# ------f1 score: {'card': 0, 'celebration': 0.4615384615384615, 'corner': 0.4, 'foul': 0.7692307692307693, 'shot': 0.33333333333333337, 'substitution': 0.5}
# ------Mean f1 score: 0.4106837606837607
# ---Mengolah folder checkpoint: checkpoint_71
# ------Accuracy: 0.4666666666666667
# ------Precision: {'card': 0, 'celebration': 0.2222222222222222, 'corner': 0.5, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.4467592592592593
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.8, 'foul': 1.0, 'shot': 0.4, 'substitution': 0.2}
# ------Mean Recall: 0.46666666666666673
# ------f1 score: {'card': 0, 'celebration': 0.2857142857142857, 'corner': 0.6153846153846154, 'foul': 0.7692307692307693, 'shot': 0.5714285714285715, 'substitution': 0.25}
# ------Mean f1 score: 0.4152930402930403
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_63-66-69-72
# ---Mengolah folder checkpoint: checkpoint_63
# ------Accuracy: 0.2
# ------Precision: {'card': 0, 'celebration': 0.5, 'corner': 0, 'foul': 0, 'shot': 0.17857142857142858, 'substitution': 0}
# ------Mean Precision: 0.1130952380952381
# ------Recall: {'card': 0.0, 'celebration': 0.2, 'corner': 0.0, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.19999999999999998
# ------f1 score: {'card': 0, 'celebration': 0.28571428571428575, 'corner': 0, 'foul': 0, 'shot': 0.30303030303030304, 'substitution': 0}
# ------Mean f1 score: 0.09812409812409813
# ---Mengolah folder checkpoint: checkpoint_66
# ------Accuracy: 0.3
# ------Precision: {'card': 0, 'celebration': 0.2857142857142857, 'corner': 0, 'foul': 0, 'shot': 0.3125, 'substitution': 0}
# ------Mean Precision: 0.09970238095238095
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0, 'celebration': 0.4210526315789473, 'corner': 0, 'foul': 0, 'shot': 0.47619047619047616, 'substitution': 0}
# ------Mean f1 score: 0.14954051796157056
# ---Mengolah folder checkpoint: checkpoint_69
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0, 'celebration': 0.3076923076923077, 'corner': 0, 'foul': 1.0, 'shot': 0.3333333333333333, 'substitution': 0}
# ------Mean Precision: 0.2735042735042735
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.4, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0, 'celebration': 0.4444444444444444, 'corner': 0, 'foul': 0.5714285714285715, 'shot': 0.5, 'substitution': 0}
# ------Mean f1 score: 0.2526455026455026
# ---Mengolah folder checkpoint: checkpoint_72
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0, 'celebration': 0.26666666666666666, 'corner': 0, 'foul': 1.0, 'shot': 0.38461538461538464, 'substitution': 0}
# ------Mean Precision: 0.2752136752136752
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 0.4, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0, 'celebration': 0.4, 'corner': 0, 'foul': 0.5714285714285715, 'shot': 0.5555555555555556, 'substitution': 0}
# ------Mean f1 score: 0.2544973544973545
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_73-76-79-82
# ---Mengolah folder checkpoint: checkpoint_73
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0.16666666666666666, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0.2857142857142857, 'corner': 0, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_76
# ------Accuracy: 0.4
# ------Precision: {'card': 0, 'celebration': 0.3076923076923077, 'corner': 0, 'foul': 0.45454545454545453, 'shot': 0.5, 'substitution': 0}
# ------Mean Precision: 0.21037296037296038
# ------Recall: {'card': 0.0, 'celebration': 0.8, 'corner': 0.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.0}
# ------Mean Recall: 0.39999999999999997
# ------f1 score: {'card': 0, 'celebration': 0.4444444444444444, 'corner': 0, 'foul': 0.625, 'shot': 0.5454545454545454, 'substitution': 0}
# ------Mean f1 score: 0.26914983164983164
# ---Mengolah folder checkpoint: checkpoint_79
# ------Accuracy: 0.6
# ------Precision: {'card': 0.25, 'celebration': 0.25, 'corner': 0.7142857142857143, 'foul': 0.8333333333333334, 'shot': 0.8333333333333334, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.5357142857142858
# ------Recall: {'card': 0.2, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0.2}
# ------Mean Recall: 0.6
# ------f1 score: {'card': 0.22222222222222224, 'celebration': 0.22222222222222224, 'corner': 0.8333333333333333, 'foul': 0.9090909090909091, 'shot': 0.9090909090909091, 'substitution': 0.25}
# ------Mean f1 score: 0.5576599326599326
# ---Mengolah folder checkpoint: checkpoint_82
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.5714285714285714, 'celebration': 0.0, 'corner': 0.8333333333333334, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.5753968253968255
# ------Recall: {'card': 0.8, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.2}
# ------Mean Recall: 0.6333333333333333
# ------f1 score: {'card': 0.6666666666666666, 'celebration': 0, 'corner': 0.9090909090909091, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.25}
# ------Mean f1 score: 0.5913299663299664
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_74-77-80-83
# ---Mengolah folder checkpoint: checkpoint_74
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0.17857142857142858, 'celebration': 0, 'corner': 1.0, 'foul': 1.0, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.36309523809523814
# ------Recall: {'card': 1.0, 'celebration': 0.0, 'corner': 0.2, 'foul': 0.2, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0.30303030303030304, 'celebration': 0, 'corner': 0.33333333333333337, 'foul': 0.33333333333333337, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.16161616161616163
# ---Mengolah folder checkpoint: checkpoint_77
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0.2, 'celebration': 0, 'corner': 0.75, 'foul': 0.45454545454545453, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.2340909090909091
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 0.6, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0.3, 'celebration': 0, 'corner': 0.6666666666666665, 'foul': 0.625, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.2652777777777778
# ...
# ------Mean f1 score: 0.2698412698412698
# ---Mengolah folder checkpoint: checkpoint_81
# ------Accuracy: 0.4
# ------Precision: {'card': 0, 'celebration': 0.4, 'corner': 0, 'foul': 0.75, 'shot': 0.35714285714285715, 'substitution': 0.2857142857142857}
# ------Mean Precision: 0.2988095238095238
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.0, 'foul': 0.6, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Recall: 0.39999999999999997
# ------f1 score: {'card': 0, 'celebration': 0.4000000000000001, 'corner': 0, 'foul': 0.6666666666666665, 'shot': 0.5263157894736842, 'substitution': 0.3333333333333333}
# ------Mean f1 score: 0.32105263157894737
# ---Mengolah folder checkpoint: checkpoint_84
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0, 'celebration': 0.3333333333333333, 'corner': 0, 'foul': 0.75, 'shot': 0.38461538461538464, 'substitution': 0.14285714285714285}
# ------Mean Precision: 0.26846764346764346
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.0, 'foul': 0.6, 'shot': 1.0, 'substitution': 0.2}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0, 'celebration': 0.3636363636363636, 'corner': 0, 'foul': 0.6666666666666665, 'shot': 0.5555555555555556, 'substitution': 0.16666666666666666}
# ------Mean f1 score: 0.29208754208754206
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_85-88-91-94
# ---Mengolah folder checkpoint: checkpoint_85
# ------Accuracy: 0.4666666666666667
# ------Precision: {'card': 0.4, 'celebration': 0.5, 'corner': 1.0, 'foul': 0, 'shot': 0.35714285714285715, 'substitution': 0.5714285714285714}
# ------Mean Precision: 0.47142857142857136
# ------Recall: {'card': 0.4, 'celebration': 0.2, 'corner': 0.4, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.8}
# ------Mean Recall: 0.4666666666666666
# ------f1 score: {'card': 0.4000000000000001, 'celebration': 0.28571428571428575, 'corner': 0.5714285714285715, 'foul': 0, 'shot': 0.5263157894736842, 'substitution': 0.6666666666666666}
# ------Mean f1 score: 0.4083542188805347
# ---Mengolah folder checkpoint: checkpoint_88
# ------Accuracy: 0.36666666666666664
# ------Precision: {'card': 0.2222222222222222, 'celebration': 0.0, 'corner': 0.5, 'foul': 0.4166666666666667, 'shot': 0, 'substitution': 0.5}
# ------Mean Precision: 0.27314814814814814
# ------Recall: {'card': 0.4, 'celebration': 0.0, 'corner': 0.2, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.6}
# ------Mean Recall: 0.3666666666666667
# ------f1 score: {'card': 0.2857142857142857, 'celebration': 0, 'corner': 0.28571428571428575, 'foul': 0.5882352941176471, 'shot': 0, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.2841864018334606
# ---Mengolah folder checkpoint: checkpoint_91
# ------Accuracy: 0.6
# ------Precision: {'card': 0.75, 'celebration': 0.2, 'corner': 0.7142857142857143, 'foul': 0.5555555555555556, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.619973544973545
# ------Recall: {'card': 0.6, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.2}
# ------Mean Recall: 0.6
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0.20000000000000004, 'corner': 0.8333333333333333, 'foul': 0.7142857142857143, 'shot': 0.7499999999999999, 'substitution': 0.28571428571428575}
# ------Mean f1 score: 0.575
# ---Mengolah folder checkpoint: checkpoint_94
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.6666666666666666, 'celebration': 0.2, 'corner': 1.0, 'foul': 0.625, 'shot': 1.0, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.6375000000000001
# ------Recall: {'card': 0.8, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.6, 'substitution': 0.2}
# ------Mean Recall: 0.6333333333333334
# ------f1 score: {'card': 0.7272727272727272, 'celebration': 0.20000000000000004, 'corner': 1.0, 'foul': 0.7692307692307693, 'shot': 0.7499999999999999, 'substitution': 0.25}
# ------Mean f1 score: 0.6160839160839161
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_86-89-92-95
# ---Mengolah folder checkpoint: checkpoint_86
# ------Accuracy: 0.3
# ------Precision: {'card': 0.2, 'celebration': 0.3333333333333333, 'corner': 0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0.08333333333333333}
# ------Mean Precision: 0.4361111111111111
# ------Recall: {'card': 0.2, 'celebration': 0.6, 'corner': 0.0, 'foul': 0.2, 'shot': 0.6, 'substitution': 0.2}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0.20000000000000004, 'celebration': 0.42857142857142855, 'corner': 0, 'foul': 0.33333333333333337, 'shot': 0.7499999999999999, 'substitution': 0.11764705882352941}
# ------Mean f1 score: 0.3049253034547152
# ---Mengolah folder checkpoint: checkpoint_89
# ------Accuracy: 0.3333333333333333
# ------Precision: {'card': 1.0, 'celebration': 0.29411764705882354, 'corner': 0, 'foul': 1.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Precision: 0.5490196078431372
# ------Recall: {'card': 0.2, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.2, 'shot': 0.6, 'substitution': 0.0}
# ------Mean Recall: 0.3333333333333333
# ------f1 score: {'card': 0.33333333333333337, 'celebration': 0.45454545454545453, 'corner': 0, 'foul': 0.33333333333333337, 'shot': 0.7499999999999999, 'substitution': 0}
# ------Mean f1 score: 0.31186868686868685
# ---Mengolah folder checkpoint: checkpoint_92
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0, 'celebration': 0.21739130434782608, 'corner': 0, 'foul': 0.3333333333333333, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Precision: 0.2584541062801932
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.2, 'shot': 0.2, 'substitution': 0.0}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.3571428571428571, 'corner': 0, 'foul': 0.25, 'shot': 0.33333333333333337, 'substitution': 0}
# ------Mean f1 score: 0.15674603174603174
# ---Mengolah folder checkpoint: checkpoint_95
# ------Accuracy: 0.43333333333333335
# ------Precision: {'card': 0.3333333333333333, 'celebration': 0.3333333333333333, 'corner': 1.0, 'foul': 0.6, 'shot': 0.5, 'substitution': 0.3333333333333333}
# ------Mean Precision: 0.5166666666666667
# ------Recall: {'card': 0.2, 'celebration': 0.8, 'corner': 0.2, 'foul': 0.6, 'shot': 0.6, 'substitution': 0.2}
# ------Mean Recall: 0.43333333333333335
# ------f1 score: {'card': 0.25, 'celebration': 0.47058823529411764, 'corner': 0.33333333333333337, 'foul': 0.6, 'shot': 0.5454545454545454, 'substitution': 0.25}
# ------Mean f1 score: 0.40822935234699936
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_87-90-93-96
# ---Mengolah folder checkpoint: checkpoint_87
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.16666666666666666, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.2857142857142857, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_90
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.16666666666666666, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.027777777777777776
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.0, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0, 'foul': 0.2857142857142857, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.047619047619047616
# ---Mengolah folder checkpoint: checkpoint_93
# ------Accuracy: 0.2
# ------Precision: {'card': 0, 'celebration': 0.25, 'corner': 0, 'foul': 0.19230769230769232, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.07371794871794872
# ------Recall: {'card': 0.0, 'celebration': 0.2, 'corner': 0.0, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.19999999999999998
# ------f1 score: {'card': 0, 'celebration': 0.22222222222222224, 'corner': 0, 'foul': 0.32258064516129037, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.0908004778972521
# ---Mengolah folder checkpoint: checkpoint_96
# ------Accuracy: 0.23333333333333334
# ------Precision: {'card': 0, 'celebration': 0.4, 'corner': 0, 'foul': 0.2, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.10000000000000002
# ------Recall: {'card': 0.0, 'celebration': 0.4, 'corner': 0.0, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.2333333333333333
# ------f1 score: {'card': 0, 'celebration': 0.4000000000000001, 'corner': 0, 'foul': 0.33333333333333337, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.12222222222222223
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_97-100-103-106
# ---Mengolah folder checkpoint: checkpoint_100
# ------Accuracy: 0.6666666666666666
# ------Precision: {'card': 0.75, 'celebration': 0.25, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.5}
# ------Mean Precision: 0.6547619047619048
# ------Recall: {'card': 0.6, 'celebration': 0.2, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6666666666666666
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0.22222222222222224, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4444444444444445}
# ------Mean f1 score: 0.6481481481481481
# ---Mengolah folder checkpoint: checkpoint_103
# ------Accuracy: 0.3
# ------Precision: {'card': 0.0, 'celebration': 0.0, 'corner': 0.5, 'foul': 0.2631578947368421, 'shot': 0, 'substitution': 0.5}
# ------Mean Precision: 0.21052631578947367
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.2, 'foul': 1.0, 'shot': 0.0, 'substitution': 0.6}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.28571428571428575, 'foul': 0.4166666666666667, 'shot': 0, 'substitution': 0.5454545454545454}
# ------Mean f1 score: 0.207972582972583
# ---Mengolah folder checkpoint: checkpoint_106
# ------Accuracy: 0.6333333333333333
# ------Precision: {'card': 0.75, 'celebration': 0.0, 'corner': 0.7142857142857143, 'foul': 0.7142857142857143, 'shot': 1.0, 'substitution': 0.4}
# ------Mean Precision: 0.5964285714285714
# ------Recall: {'card': 0.6, 'celebration': 0.0, 'corner': 1.0, 'foul': 1.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.6333333333333334
# ------f1 score: {'card': 0.6666666666666665, 'celebration': 0, 'corner': 0.8333333333333333, 'foul': 0.8333333333333333, 'shot': 0.888888888888889, 'substitution': 0.4000000000000001}
# ------Mean f1 score: 0.6037037037037036
# ---Mengolah folder checkpoint: checkpoint_97
# ------Accuracy: 0.2
# ------Precision: {'card': 0, 'celebration': 0.19230769230769232, 'corner': 0, 'foul': 0.25, 'shot': 0, 'substitution': 0}
# ------Mean Precision: 0.07371794871794872
# ------Recall: {'card': 0.0, 'celebration': 1.0, 'corner': 0.0, 'foul': 0.2, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.19999999999999998
# ------f1 score: {'card': 0, 'celebration': 0.32258064516129037, 'corner': 0, 'foul': 0.22222222222222224, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.0908004778972521
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_98-101-104-107
# ---Mengolah folder checkpoint: checkpoint_101
# ------Accuracy: 0.3
# ------Precision: {'card': 0.0, 'celebration': 0, 'corner': 0.23809523809523808, 'foul': 0, 'shot': 0.5, 'substitution': 0}
# ------Mean Precision: 0.12301587301587302
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.8, 'substitution': 0.0}
# ------Mean Recall: 0.3
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3846153846153846, 'foul': 0, 'shot': 0.6153846153846154, 'substitution': 0}
# ------Mean f1 score: 0.16666666666666666
# ---Mengolah folder checkpoint: checkpoint_104
# ------Accuracy: 0.4
# ------Precision: {'card': 0.14285714285714285, 'celebration': 0, 'corner': 0.38461538461538464, 'foul': 0, 'shot': 0.5, 'substitution': 1.0}
# ------Mean Precision: 0.3379120879120879
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.8, 'substitution': 0.4}
# ------Mean Recall: 0.39999999999999997
# ------f1 score: {'card': 0.16666666666666666, 'celebration': 0, 'corner': 0.5555555555555556, 'foul': 0, 'shot': 0.6153846153846154, 'substitution': 0.5714285714285715}
# ------Mean f1 score: 0.3181725681725682
# ---Mengolah folder checkpoint: checkpoint_107
# ------Accuracy: 0.5333333333333333
# ------Precision: {'card': 0.16666666666666666, 'celebration': 0, 'corner': 0.5555555555555556, 'foul': 1.0, 'shot': 0.5, 'substitution': 1.0}
# ------Mean Precision: 0.5370370370370371
# ------Recall: {'card': 0.2, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.4, 'shot': 1.0, 'substitution': 0.6}
# ------Mean Recall: 0.5333333333333333
# ------f1 score: {'card': 0.1818181818181818, 'celebration': 0, 'corner': 0.7142857142857143, 'foul': 0.5714285714285715, 'shot': 0.6666666666666666, 'substitution': 0.7499999999999999}
# ------Mean f1 score: 0.4806998556998557
# ---Mengolah folder checkpoint: checkpoint_98
# ------Accuracy: 0.26666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.21428571428571427, 'foul': 0, 'shot': 0.3125, 'substitution': 0}
# ------Mean Precision: 0.08779761904761905
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 0.6, 'foul': 0.0, 'shot': 1.0, 'substitution': 0.0}
# ------Mean Recall: 0.26666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3157894736842105, 'foul': 0, 'shot': 0.47619047619047616, 'substitution': 0}
# ------Mean f1 score: 0.13199665831244778
# ==========================================
# Mengolah folder konfigurasi: konfigurasi_99-102-105-108
# ---Mengolah folder checkpoint: checkpoint_102
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.18518518518518517, 'foul': 0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Precision: 0.030864197530864196
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3125, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.052083333333333336
# ---Mengolah folder checkpoint: checkpoint_105
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.18518518518518517, 'foul': 0, 'shot': 0.0, 'substitution': 0}
# ------Mean Precision: 0.030864197530864196
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3125, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.052083333333333336
# ---Mengolah folder checkpoint: checkpoint_108
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.17857142857142858, 'foul': 0, 'shot': 0.0, 'substitution': 0}
# ------Mean Precision: 0.029761904761904764
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.30303030303030304, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.050505050505050504
# ---Mengolah folder checkpoint: checkpoint_99
# ------Accuracy: 0.16666666666666666
# ------Precision: {'card': 0, 'celebration': 0, 'corner': 0.20833333333333334, 'foul': 0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Precision: 0.034722222222222224
# ------Recall: {'card': 0.0, 'celebration': 0.0, 'corner': 1.0, 'foul': 0.0, 'shot': 0.0, 'substitution': 0.0}
# ------Mean Recall: 0.16666666666666666
# ------f1 score: {'card': 0, 'celebration': 0, 'corner': 0.3448275862068966, 'foul': 0, 'shot': 0, 'substitution': 0}
# ------Mean f1 score: 0.0574712643678161
